# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread("/kaggle/input/sadams-practice-images-for-computer-vision/j10c_b.jpeg")

# %%
# img  = np.zeros((20,30,3),np.uint8)

# %%
img.shape
# Out:
# (420, 732, 3)

# %%
# cv.line(img,(5,10),(10,10),(255,0,0),1)

# %%
plt.imshow(cv.cvtColor(img,cv.COLOR_BGR2RGB))

# %%
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
his = cv.calcHist([img],[0],None,[256],[0,256])

# %%
plt.plot(his)

# %%
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
plt.imshow(img,cmap="gray")

# %%
img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
img = cv.equalizeHist(img)

# %%
plt.imshow(img,cmap="gray")

# %%
clahe = cv.createCLAHE(clipLimit=20,tileGridSize=(3,3))
imgC = clahe.apply(img)

# %%
plt.imshow(imgC,cmap="gray")
