# %% [markdown]
# # Image Alignment
# **Satya Mallick, LearnOpenCV.com**

# %% [markdown]
# ## Align an image to a template.
# ![alt text](https://learnopencv.com/wp-content/uploads/2023/03/opencv_bootcamp_08_image-alignment-using-opencv.jpg "Image Alignment")

# %% [markdown]
# ## Theory
#
# 1. A **Homography** transforms a square to arbitrary quad.
#
# ![alt text](https://learnopencv.com/wp-content/uploads/2023/03/opencv_bootcamp_08_motion-models.jpg "Motion Models")

# %% [markdown]
# ## Theory
#
# 2. Images of two planes are related by a **Homography**
# 3. We need **4 corresponding points** to estimate Homography
#
# > **Algorithm**
# >
# >    1. Take the query image and convert it to grayscale.
# >    2. Now Initialize the ORB detector and detect the keypoints in query image and scene.
# >    3. Compute the descriptors belonging to both the images.
# >    4. Match the keypoints using Brute Force Matcher.
# >    5. Show the matched images.
#
# !["Homography Example"](https://learnopencv.com/wp-content/uploads/2023/03/opencv_bootcamp_08_homography-example.jpg)

# %%
# Imports
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

# %matplotlib inline

# %% [markdown]
# ##  <font style="color:black">Download Assets</font>

# %%
def download_and_unzip(url, save_path):
    print(f"Downloading and extracting assests....", end="")

    # Downloading zip file using urllib package.
    urlretrieve(url, save_path)

    try:
        # Extracting zip file using the zipfile package.
        with ZipFile(save_path) as z:
            # Extract ZIP file contents in the same directory.
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/zuwnn6rqe0f4zgh/opencv_bootcamp_assets_NB8.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), "images/tmpImage/opencv_bootcamp_assets_NB8.zip")

# Download if assest ZIP does not exists.
if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)

# %% [markdown]
# ## Step 1: Read Tempalate and Scanned Image

# %%
# Read reference image
refFilename = "images/tmpImage/form.jpg"
print("Reading reference image:", refFilename)
im1 = cv2.imread(refFilename, cv2.IMREAD_COLOR)
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)

# Read image to be aligned
imFilename = "images/tmpImage/scanned-form.jpg"
print("Reading image to align:", imFilename)
im2 = cv2.imread(imFilename, cv2.IMREAD_COLOR)
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)
# Out:
# Reading reference image: images/tmpImage/form.jpg
# Reading image to align: images/tmpImage/scanned-form.jpg

# %%
# Display Images

plt.figure(figsize=[20, 10]);
plt.subplot(121); plt.axis('off'); plt.imshow(im1); plt.title("Original Form")
plt.subplot(122); plt.axis('off'); plt.imshow(im2); plt.title("Scanned Form")
# Out:
# Text(0.5, 1.0, 'Scanned Form')

# %% [markdown]
# ## Step 2: Find keypoints in both Images
#
# Think of keypoints as corner points that are stable under image transformations

# %%
# Convert images to grayscale
im1_gray = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
im2_gray = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)


# Detect ORB features and compute descriptors.
MAX_NUM_FEATURES = 500
orb = cv2.ORB_create(MAX_NUM_FEATURES)
keypoints1, descriptors1 = orb.detectAndCompute(im1_gray, None)
keypoints2, descriptors2 = orb.detectAndCompute(im2_gray, None)
mask = np.ones(im1_gray.size,np.uint8)
keypoints3, descriptors3 = orb.detectAndCompute(im2_gray, mask)
# Display
im1_display = cv2.drawKeypoints(im1, keypoints1, outImage=np.array([]),
                                color=(255, 0, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
im3_display = cv2.drawKeypoints(im2, keypoints3, outImage=np.array([]),
                                color=(255, 0, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
im2_display = cv2.drawKeypoints(im2, keypoints2, outImage=np.array([]),
                                color=(255, 0, 0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
plt.figure(figsize=[20,10])
plt.subplot(131); plt.axis('off'); plt.imshow(im1_display); plt.title("Original Form");
plt.subplot(132); plt.axis('off'); plt.imshow(im2_display); plt.title("Scanned Form");
plt.subplot(133); plt.axis('off'); plt.imshow(im3_display); plt.title("Scanned Form MASK");

# %% [markdown]
# ## Step 3 : Match keypoints in the two image

# %%
# enum  	{
#   FLANNBASED = 1,
#   BRUTEFORCE = 2,
#   BRUTEFORCE_L1 = 3,
#   BRUTEFORCE_HAMMING = 4,
#   BRUTEFORCE_HAMMINGLUT = 5,
#   BRUTEFORCE_SL2 = 6
# }
# Match features.
matcher = cv2.DescriptorMatcher_create(cv2.DESCRIPTOR_MATCHER_BRUTEFORCE_HAMMING)

# Converting to list for sorting as tuples are immutable objects.
# matches = list(matcher.match(descriptors1, descriptors2, None))
matches = list(matcher.match(descriptors1, descriptors2, None))
matches2 = list(matcher.match(descriptors1, descriptors3, None))

# Sort matches by score
matches.sort(key=lambda x: x.distance, reverse=False)
matches2.sort(key=lambda x: x.distance, reverse=False)

# Remove not so good matches
numGoodMatches = int(len(matches) * 0.1)
numGoodMatches2 = int(len(matches2) * 0.1)
matches = matches[:numGoodMatches]
matches2 = matches2[:numGoodMatches2]

# %%
# Draw top matches
im_matches = cv2.drawMatches(im1, keypoints1, im2, keypoints2, matches, None)
im_matches2 = cv2.drawMatches(im1, keypoints1, im2, keypoints3, matches2, None)

plt.figure(figsize=[40, 10])
plt.subplot(131); plt.imshow(im_matches);plt.axis("off");plt.title("Original Form")
plt.subplot(132); plt.imshow(im_matches2);plt.axis("off");plt.title("scan1 Form")
# Out:
# Text(0.5, 1.0, 'scan1 Form')

# %% [markdown]
# ## Step 4:  Find Homography

# %%
# Extract location of good matches
points1 = np.zeros((len(matches), 2), dtype=np.float32)
points2 = np.zeros((len(matches), 2), dtype=np.float32)

points3 = np.zeros((len(matches2), 2), dtype=np.float32)
points4 = np.zeros((len(matches2), 2), dtype=np.float32)

for i, match in enumerate(matches):
    points1[i, :] = keypoints1[match.queryIdx].pt
    points2[i, :] = keypoints2[match.trainIdx].pt

for i, match in enumerate(matches2):
    points3[i, :] = keypoints1[match.queryIdx].pt
    points4[i, :] = keypoints3[match.trainIdx].pt

# Find homography
h, mask = cv2.findHomography(points2, points1, cv2.RANSAC)
h2, mask2 = cv2.findHomography(points4, points3, cv2.RANSAC)

print(h)
# Out:
# [[ 1.40692593e+00 -2.04020505e-01 -6.60865029e+00]
#  [ 2.23293008e-01  1.54696537e+00 -4.89454082e+02]
#  [-6.80320989e-05  1.58905649e-04  1.00000000e+00]]

# %% [markdown]
# ## Step 5: Warp image

# %%
# Use homography to warp image
height, width, channels = im1.shape
im2_reg = cv2.warpPerspective(im2, h, (width, height))
im3_reg = cv2.warpPerspective(im2, h2, (width, height))
cv2.getPerspectiveTransform(keypoints1, keypoints2)

# Display results
plt.figure(figsize=[20, 10])
plt.subplot(131);plt.imshow(im1);    plt.axis("off");plt.title("Original Form")
plt.subplot(132);plt.imshow(im2_reg);plt.axis("off");plt.title("Scanned Form")
plt.subplot(133);plt.imshow(im3_reg);plt.axis("off");plt.title("Scanned Mask Form")
# Out:
# Text(0.5, 1.0, 'Scanned Mask Form')

# %%
<embed width="100%" height="500" src="Feature matching using ORB algorithm in Python-OpenCV - GeeksforGeeks.pdf"/>
